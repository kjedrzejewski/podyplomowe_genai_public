# %% [markdown]
# # Zadanie - Analiza wywiadów ustrukturyzowanych

# %% [markdown]
# Folder `004-02. LLM-zadanie-data` zawiera dane z wywiadów przeprowadzonych wśród przedsiębiorców - scenariusz oraz zebrane odpowiedzi.
#
# Twoim zadaniem jest ekstrakcja informacji z tych wywiadów, a następnie ich wizualizacja. Przykłady wizualizacji możesz znaleźć poniżej.
#
# ![004-02. motivation.png](<attachment:004-02. motivation.png>)
#
# ![004-02. prosperity.png](<attachment:004-02. prosperity.png>)
#
# ![004-02. sentiment.png](<attachment:004-02. sentiment.png>)

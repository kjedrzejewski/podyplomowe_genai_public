# %% [markdown]
# # Zadanie - Niedźwiedź w Nowym Jorku

# %% [markdown]
# Używając Stable Diffusion, wygeneruj zdjęcie różowego niedźwiedzia na Times Square. Grafika ma być fotorealistyczna i mieć rozmiary 1280x960.
#
# ![002-02. pink bear.png](<attachment:002-02. pink bear.png>)
